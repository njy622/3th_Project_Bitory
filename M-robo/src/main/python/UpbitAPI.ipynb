# %% [markdown]
# ### 업비트 API 데이터 확인해보기

# %%
import openai
import os

BitUp_Access_KEY = os.getenv("BitUp_Access_OPENAI_API_KEY")
BitUp_Secret_KEY = os.getenv("BitUp_Secret_OPENAI_API_KEY")

# %% [markdown]
# ## 가상화폐 종목 KRW모음! 화폐단위만 예쁘게정리하자!

# %%
# 마켓 코드 조회>/
url = "https://api.upbit.com/v1/ticker"

headers = {"accept": "application/json"}

querystring = {"markets":"KRW-BTC"}

response = requests.get(url, headers=headers, params=querystring)
coin_shop = response.json()
coin_shop[0]['market'], len(coin_shop)
# Out:
# ('KRW-BTC', 1)

# %%
coin_shop
coin_shop_list = []

for i in range(len(coin_shop)):
    if coin_shop[i]['market'][:4] in 'KRW-':
        coin_shop_list.append(coin_shop[i])

coin_shop_list
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date': '20240127',
#   'trade_time': '031801',
#   'trade_date_kst': '20240127',
#   'trade_time_kst': '121801',
#   'trade_timestamp': 1706325481009,
#   'opening_price': 57526000.0,
#   'high_price': 57950000.0,
#   'low_price': 57345000.0,
#   'trade_price': 57706000.0,
#   'prev_closing_price': 57503000.0,
#   'change': 'RISE',
#   'change_price': 203000.0,
#   'change_rate': 0.0035302506,
#   'signed_change_price': 203000.0,
#   'signed_change_rate': 0.0035302506,
#   'trade_volume': 0.00026884,
#   'acc_trade_price': 34860580782.29675,
#   'acc_trade_price_24h': 311478335280.30774,
#   'acc_trade_volume': 604.38133569,
#   'acc_trade_volume_24h': 5473.0139883,
#   'highest_52_week_price': 66779000.0,
#   'highest_52_week_date': '2024-01-11',
#   'lowest_52_week_price': 26707000.0,
#   'lowest_52_week_date': '2023-03-10',
#   'timestamp': 1706325481037}]

# %%
coin_shop_dict = pd.DataFrame(coin_shop_list)
coin_shop_dict
# Out:
#     market trade_date trade_time trade_date_kst trade_time_kst  \
# 0  KRW-BTC   20240127     031801       20240127         121801
#
#    trade_timestamp  opening_price  high_price   low_price  trade_price  ...  \
# 0    1706325481009     57526000.0  57950000.0  57345000.0   57706000.0  ...
#
#    trade_volume acc_trade_price  acc_trade_price_24h  acc_trade_volume  \
# 0      0.000269    3.486058e+10         3.114783e+11        604.381336
#
#    acc_trade_volume_24h  highest_52_week_price  highest_52_week_date  \
# 0           5473.013988             66779000.0            2024-01-11
#
#    lowest_52_week_price  lowest_52_week_date      timestamp
# 0            26707000.0           2023-03-10  1706325481037
#
# [1 rows x 26 columns]

# %%
coin_shop_dict.to_csv("가상화폐종목별 이름(KRW분류).csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 coin_shop_dict.to_csv("가상화폐종목별 이름(KRW분류).csv")
#
# NameError: name 'coin_shop_dict' is not defined

# %%
coin_shop_dict.market
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 coin_shop_dict.market
#
# NameError: name 'coin_shop_dict' is not defined

# %% [markdown]
# ### 현재가로 필요한 데이터만 긁어오기

# %%
import requests

url = "https://api.upbit.com/v1/ticker"

headers = {"accept": "application/json"}

querystring = {"markets":"KRW-BTC"}

response = requests.get(url, headers=headers, params=querystring)

response.json()
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date': '20240127',
#   'trade_time': '031810',
#   'trade_date_kst': '20240127',
#   'trade_time_kst': '121810',
#   'trade_timestamp': 1706325490719,
#   'opening_price': 57526000.0,
#   'high_price': 57950000.0,
#   'low_price': 57345000.0,
#   'trade_price': 57705000.0,
#   'prev_closing_price': 57503000.0,
#   'change': 'RISE',
#   'change_price': 202000.0,
#   'change_rate': 0.0035128602,
#   'signed_change_price': 202000.0,
#   'signed_change_rate': 0.0035128602,
#   'trade_volume': 0.01534615,
#   'acc_trade_price': 34873727648.30752,
#   'acc_trade_price_24h': 311478335280.30774,
#   'acc_trade_volume': 604.60915951,
#   'acc_trade_volume_24h': 5473.0139883,
#   'highest_52_week_price': 66779000.0,
#   'highest_52_week_date': '2024-01-11',
#   'lowest_52_week_price': 26707000.0,
#   'lowest_52_week_date': '2023-03-10',
#   'timestamp': 1706325490731}]

# %%
explanation = pd.read_csv('./static/현재가필드명.csv')
explanation
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 explanation = pd.read_csv('./static/현재가필드명.csv')
#       2 explanation
#
# NameError: name 'pd' is not defined

# %%
explanation_name = []
for i in range(len(explanation.필드)):
    explanation_name.append(explanation.필드[i] + ' ('+explanation.설명[i]+')')
explanation_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 explanation_name = []
# ----> 2 for i in range(len(explanation.필드)):
#       3     explanation_name.append(explanation.필드[i] + ' ('+explanation.설명[i]+')')
#       4 explanation_name
#
# NameError: name 'explanation' is not defined

# %%
explanation_name[0].split()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 explanation_name[0].split()
#
# IndexError: list index out of range

# %%
price_list = []
total_price = []

for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 4
#       1 price_list = []
#       2 total_price = []
# ----> 4 for i in coin_shop_dict.market:
#       5     url = "https://api.upbit.com/v1/ticker"
#       6     headers = {"accept": "application/json"}
#
# NameError: name 'coin_shop_dict' is not defined

# %%
for i in range(len(price_list2)):
    for key, value in price_list2[i].items():
        print(key, value)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 for i in range(len(price_list2)):
#       2     for key, value in price_list2[i].items():
#       3         print(key, value)
#
# NameError: name 'price_list2' is not defined

# %%
len(explanation_name)
# Out:
# 0

# %%
explanation_name[17:]
# Out:
# []

# %%
for j in explanation_name:
            print(j)

# %%
price_list2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 price_list2
#
# NameError: name 'price_list2' is not defined

# %%
for key, value in price_list2[i].items():
    for i in range(len(price_list2)):
        for j in range(len(explanation_name)):
            if key == explanation_name[j].split()[0]:
                price_list2[i][explanation_name[j]] = price_list2[i].pop(explanation_name[j].split()[0])
                

price_list2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 for key, value in price_list2[i].items():
#       2     for i in range(len(price_list2)):
#       3         for j in range(len(explanation_name)):
#
# NameError: name 'price_list2' is not defined

# %%
explanation_name[20].split()[0]
# Out:
# 'acc_trade_volume_24h'

# %%
explanation_name[20].split()[0] == 'acc_trade_volume_24h'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 explanation_name[20].split()[0] == 'acc_trade_volume_24h'
#
# IndexError: list index out of range

# %%
price_list2[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 price_list2[0]
#
# NameError: name 'price_list2' is not defined

# %%
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date': '20240127',
#   'trade_time': '031659',
#   'trade_date_kst': '20240127',
#   'trade_time_kst': '121659',
#   'trade_timestamp': 1706325419010,
#   'opening_price': 57526000.0,
#   'high_price': 57950000.0,
#   'low_price': 57345000.0,
#   'trade_price': 57700000.0,
#   'prev_closing_price': 57503000.0,
#   'change': 'RISE',
#   'change_price': 197000.0,
#   'change_rate': 0.0034259082,
#   'signed_change_price': 197000.0,
#   'signed_change_rate': 0.0034259082,
#   'trade_volume': 0.02696813,
#   'acc_trade_price': 34806397273.65702,
#   'acc_trade_price_24h': 310902468097.1856,
#   'acc_trade_volume': 603.44253831,
#   'acc_trade_volume_24h': 5463.02421659,
#   'highest_52_week_price': 66779000.0,
#   'highest_52_week_date': '2024-01-11',
#   'lowest_52_week_price': 26707000.0,
#   'lowest_52_week_date': '2023-03-10',
#   'timestamp': 1706325419037},
#  {'market': 'KRW-ETH',
#   'trade_date': '20240127',
#   'trade_time': '031649',
# ...

# %%
import requests

price_list = []
total_price = []

for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

for i in range(len(price_list2)):
    for key, value in price_list2[i].items():
        for j in range(len(explanation_name)):
            if key == explanation_name[j].split()[0]:
                price_list2[i][explanation_name[j]] = price_list2[i].pop(explanation_name[j].split()[0])
                


price_list2[0]
# Out:
# {'market': 'KRW-BTC',
#  'trade_date': '20240127',
#  'trade_time': '031819',
#  'trade_date_kst': '20240127',
#  'trade_time_kst': '121819',
#  'trade_timestamp': 1706325499798,
#  'opening_price': 57526000.0,
#  'high_price': 57950000.0,
#  'low_price': 57345000.0,
#  'trade_price': 57706000.0,
#  'prev_closing_price': 57503000.0,
#  'change': 'RISE',
#  'change_price': 203000.0,
#  'change_rate': 0.0035302506,
#  'signed_change_price': 203000.0,
#  'signed_change_rate': 0.0035302506,
#  'trade_volume': 8.837e-05,
#  'acc_trade_price': 34882230873.50856,
#  'acc_trade_price_24h': 311478335280.30774,
#  'acc_trade_volume': 604.75651548,
#  'acc_trade_volume_24h': 5473.0139883,
#  'highest_52_week_price': 66779000.0,
#  'highest_52_week_date': '2024-01-11',
#  'lowest_52_week_price': 26707000.0,
#  'lowest_52_week_date': '2023-03-10',
#  'timestamp': 1706325499824}

# %%
price_list2[0]
# Out:
# {'market': 'KRW-BTC',
#  'trade_date': '20240127',
#  'trade_time': '031819',
#  'trade_date_kst': '20240127',
#  'trade_time_kst': '121819',
#  'trade_timestamp': 1706325499798,
#  'opening_price': 57526000.0,
#  'high_price': 57950000.0,
#  'low_price': 57345000.0,
#  'trade_price': 57706000.0,
#  'prev_closing_price': 57503000.0,
#  'change': 'RISE',
#  'change_price': 203000.0,
#  'change_rate': 0.0035302506,
#  'signed_change_price': 203000.0,
#  'signed_change_rate': 0.0035302506,
#  'trade_volume': 8.837e-05,
#  'acc_trade_price': 34882230873.50856,
#  'acc_trade_price_24h': 311478335280.30774,
#  'acc_trade_volume': 604.75651548,
#  'acc_trade_volume_24h': 5473.0139883,
#  'highest_52_week_price': 66779000.0,
#  'highest_52_week_date': '2024-01-11',
#  'lowest_52_week_price': 26707000.0,
#  'lowest_52_week_date': '2023-03-10',
#  'timestamp': 1706325499824}

# %%
import requests

price_list = []
total_price = []

for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

    
for j in range(len(price_list2)):
    oder_date = '일시 : ' + price_list2[j]['trade_date_kst'] + price_list2[j]['trade_time_kst'] 
    currency = '종목 : ' + price_list2[j]['market']
    trade_price = '거래가격 : ' + str(price_list2[j]['trade_price'])
    total_price.append(oder_date +' / '+ currency +' / ' + trade_price +' / ' + change_price)
total_price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 24
#      22     currency = '종목 : ' + price_list2[j]['market']
#      23     trade_price = '거래가격 : ' + str(price_list2[j]['trade_price'])
# ---> 24     total_price.append(oder_date +' / '+ currency +' / ' + trade_price +' / ' + change_price)
#      25 total_price
#
# NameError: name 'change_price' is not defined

# %%
market_name = pd.read_csv('./가상화폐종목별 이름(KRW분류).csv', index_col='Unnamed: 0')
market_name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 market_name = pd.read_csv('./가상화폐종목별 이름(KRW분류).csv', index_col='Unnamed: 0')
#       2 market_name
#
# NameError: name 'pd' is not defined

# %%
market_full_name = market_name['market'] +' ('+ market_name['korean_name'] +'/'+ market_name['english_name'] + ')'
market_full_name
# Out:
# 0            KRW-BTC (비트코인/Bitcoin)
# 1           KRW-ETH (이더리움/Ethereum)
# 2                  KRW-NEO (네오/NEO)
# 3                KRW-MTL (메탈/Metal)
# 4               KRW-XRP (리플/Ripple)
#                    ...
# 113    KRW-IMX (이뮤터블엑스/Immutable X)
# 114                KRW-SEI (세이/Sei)
# 115              KRW-MINA (미나/Mina)
# 116      KRW-CTC (크레딧코인/Creditcoin)
# 117            KRW-ASTR (아스타/Astar)
# Length: 118, dtype: object

# %%
market_full_name[0].split()[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 market_full_name[0].split()[0]
#
# NameError: name 'market_full_name' is not defined

# %%
import requests

price_list = []
total_price = []

for i in market_full_name:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i.split()[0]}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)

    
for j in range(len(price_list2)):
    oder_date = '일시 : ' + price_list2[j]['trade_date_kst'] + price_list2[j]['trade_time_kst'] 
    for i in range(len(market_full_name)):
        if (market_full_name[i].split()[0]== price_list2[j]['market']):
            currency = '종목 : ' + market_full_name[i]
    trade_price = '거래가격 : ' + str(price_list2[j]['trade_price'])
    change_price = '수수료 : ' + str(price_list2[j]['change_price']) + " (수수료율 : "+ str(price_list2[j]['change_rate']) +" %)"
    total_price.append(oder_date +' / '+ currency +' / ' + trade_price +' / ' + change_price)
total_price
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 6
#       3 price_list = []
#       4 total_price = []
# ----> 6 for i in market_full_name:
#       7     url = "https://api.upbit.com/v1/ticker"
#       8     headers = {"accept": "application/json"}
#
# NameError: name 'market_full_name' is not defined

# %%
import requests

price_list = []
total_price = []

for i in market_full_name:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i.split()[0]}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())
price_list2 = []
for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date': '20240125',
#   'trade_time': '085214',
#   'trade_date_kst': '20240125',
#   'trade_time_kst': '175214',
#   'trade_timestamp': 1706172734169,
#   'opening_price': 55200000.0,
#   'high_price': 55401000.0,
#   'low_price': 54900000.0,
#   'trade_price': 55230000.0,
#   'prev_closing_price': 55200000.0,
#   'change': 'RISE',
#   'change_price': 30000.0,
#   'change_rate': 0.0005434783,
#   'signed_change_price': 30000.0,
#   'signed_change_rate': 0.0005434783,
#   'trade_volume': 0.03965524,
#   'acc_trade_price': 57969309660.79715,
#   'acc_trade_price_24h': 158471617045.5294,
#   'acc_trade_volume': 1051.52469541,
#   'acc_trade_volume_24h': 2871.99428629,
#   'highest_52_week_price': 66779000.0,
#   'highest_52_week_date': '2024-01-11',
#   'lowest_52_week_price': 26707000.0,
#   'lowest_52_week_date': '2023-03-10',
#   'timestamp': 1706172734184},
#  {'market': 'KRW-ETH',
#   'trade_date': '20240125',
#   'trade_time': '085214',
# ...

# %%
nameList = pd.read_csv('./static/가상화폐종목별 이름(KRW분류).csv')
nameList
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 nameList = pd.read_csv('./static/가상화폐종목별 이름(KRW분류).csv')
#       2 nameList
#
# NameError: name 'pd' is not defined

# %%
price_df_list = price_df['market'].to_list()
price_df_list
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLYX',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-CVC',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-JST',
#  'KRW-CRO',
#  'KRW-TON',
#  'KRW-SXP',
#  'KRW-HUNT',
#  'KRW-PLA',
#  'KRW-DOT',
#  'KRW-MVL',
#  'KRW-STRAX',
#  'KRW-AQT',
#  'KRW-AXS',
#  'KRW-STX',
#  'KRW-XEC',
#  'KRW-SOL',
#  'KRW-MATIC',
#  'KRW-AAVE',
#  'KRW-1INCH',
#  'KRW-ALGO',
#  'KRW-NEAR',
#  'KRW-AVAX',
#  'KRW-IMX',
#  'KRW-MINA',
#  'KRW-ASTR']

# %%
import requests
import pandas as pd


price_list = []
price_list2 = []
price_list3 = []
total_price = []

coin_shop_dict = pd.read_csv("./static/메이저종목.csv")

for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())

for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

price_df = pd.DataFrame(price_list2)
for k in range(len(nameList['market'].to_list())):
    for i in nameList['market']:
        for j in price_df_list:
            if i == j:
                price_df['market'] = i + ' ('+ nameList['korean_name'] +'/'+ nameList['english_name'] + ')'

            else:
                price_df['market'] = i

price_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 26
#      23 price_list2
#      25 price_df = pd.DataFrame(price_list2)
# ---> 26 for k in range(len(nameList['market'].to_list())):
#      27     for i in nameList['market']:
#      28         for j in price_df_list:
#
# NameError: name 'nameList' is not defined

# %% [markdown]
# # KRW마켓 종목별 현재가 전체항목

# %%
## KRW마켓 종목별 현재가 전체항목

import requests

price_list = []
price_list2 = []
price_list3 = []
total_price = []

coin_shop_dict = pd.read_csv("./가상화폐종목별 이름(KRW분류).csv")

for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())

for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

    
for j in range(len(price_list2)):
    for i in range(len(price_list2)):
        for key, value in price_list2[i].items():
            for j in range(len(explanation_name)):
                if key == explanation_name[j].split()[0]:
                    key = explanation_name[j] + ': ' + str(price_list2[i][key])
                    price_list3.append(key)

total_price =[]
for i in range(len(price_list3)):
    total_price.append(price_list3[26*i:26*(i+1)])
total_price
# Out:
# []

# %% [markdown]
# # 모든마켓 종목별 현재가 전체항목

# %%
## 모든 마켓 종목별 현재가 전체항목

import requests
import pandas as pd

price_list = []
price_list2 = []
price_list3 = []
total_price2 = []

coin_shop_dict = pd.read_csv("./static/가상화폐종목별 이름.csv")
explanation = pd.read_csv('./static/현재가필드명.csv')
explanation_name = []
for i in range(len(explanation.필드)):
    explanation_name.append(explanation.필드[i] + ' ('+explanation.설명[i]+')')


for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())

for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

    
for j in range(len(price_list2)):
    for i in range(len(price_list2)):
        for key, value in price_list2[i].items():
            for j in range(len(explanation_name)):
                if key == explanation_name[j].split()[0]:
                    key = explanation_name[j] + ': ' + str(price_list2[i][key])
                    price_list3.append(key)


for i in range(len(price_list3)):
    total_price2.append(price_list3[26*i:26*(i+1)])
total_price2
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[37], line 22
#      20     headers = {"accept": "application/json"}
#      21     querystring = {"markets":i}
# ---> 22     response = requests.get(url, headers=headers, params=querystring)
#      23     price_list.append(response.json())
#      25 for i in price_list:
#
# File c:\Users\mwsong\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\mwsong\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
# ...

# %%
## 모든 마켓 종목별 현재가 전체항목

import requests
import pandas as pd

price_list = []
price_list2 = []
price_list3 = []
total_price2 = []

coin_shop_dict = pd.read_csv("./static/메이저종목.csv")
explanation = pd.read_csv('./static/현재가필드명.csv')
explanation_name = []
for i in range(len(explanation.필드)):
    explanation_name.append(explanation.필드[i] + ' ('+explanation.설명[i]+')')


for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())

price_list

for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

for j in range(len(price_list2)):
    for i in range(len(price_list2)):
        for key, value in price_list2[i].items():
            for j in range(len(explanation_name)):
                if key == explanation_name[j].split()[0]:
                    key = explanation_name[j] + ': ' + str(price_list2[i][key])
    

price_list3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 35
#      33 for j in range(len(price_list2)):
#      34     for i in range(len(price_list2)):
# ---> 35         for key, value in price_list2[i].items():
#      36             for j in range(len(explanation_name)):
#      37                 if key == explanation_name[j].split()[0]:
#
# AttributeError: 'str' object has no attribute 'items'

# %%
## 메이저 종목 1

import requests
import pandas as pd

price_list = []
price_list2 = []
price_list3 = []
total_price2 = []

coin_shop_dict = pd.read_csv("./static/메이저종목.csv")
explanation = pd.read_csv('./static/현재가필드명.csv')
explanation_name = []
for i in range(len(explanation.필드)):
    explanation_name.append(explanation.필드[i] + ' ('+explanation.설명[i]+')')


for i in coin_shop_dict.market:
    url = "https://api.upbit.com/v1/ticker"
    headers = {"accept": "application/json"}
    querystring = {"markets":i}
    response = requests.get(url, headers=headers, params=querystring)
    price_list.append(response.json())

for i in price_list:
    for j in i:
        if j != "{'name': 'too_many_requests'}" and j != 'name':
            price_list2.append(j)
price_list2

    
for i in range(len(price_list2)):
    for key, value in price_list2[i].items():
        for j in range(len(explanation_name)):
            if key == explanation_name[j].split()[0]:
                price_list2[i][explanation_name[j]] = price_list2[i].pop(explanation_name[j].split()[0])
                


price_list
# Out:
# [[{'acc_trade_price': 48511601718.49644,
#    'acc_trade_price_24h': 315047039670.8635,
#    'acc_trade_volume': 840.80721616,
#    'acc_trade_volume_24h': 5527.1425397,
#    'highest_52_week_price': 66779000.0,
#    'highest_52_week_date': '2024-01-11',
#    'lowest_52_week_price': 26707000.0,
#    'lowest_52_week_date': '2023-03-10',
#    'timestamp': 1706336296290,
#    'market (종목구분코드)': 'KRW-BTC',
#    'trade_date (최근거래일자(UTC))': '20240127',
#    'trade_time (최근거래시각(UTC))': '061816',
#    'trade_date_kst (최근거래일자(KST))': '20240127',
#    'trade_time_kst (최근거래시각(KST))': '151816',
#    'trade_timestamp (최근거래일시(UTC))': 1706336296263,
#    'opening_price (시가)': 57526000.0,
#    'high_price (고가)': 57950000.0,
#    'low_price (저가)': 57345000.0,
#    'trade_price (종가(현재가))': 57773000.0,
#    'prev_closing_price (전일종가(UTC0시기준))': 57503000.0,
#    'change (EVEN:보합/RISE:상승/FALL:하락)': 'RISE',
#    'change_price (변화액의절대값)': 270000.0,
#    'change_rate (변화율의절대값)': 0.0046954072,
# ...

# %%
for i in range(len(price_list2)):
    for key, value in price_list2[i].items():
        for j in range(len(explanation_name)):
            if key == explanation_name[j].split()[0]:
                price_list2[i][explanation_name[j]] = price_list2[i].pop(explanation_name[j].split()[0])
                


price_list
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 2
#       1 for i in range(len(price_list2)):
# ----> 2     for key, value in price_list2[i].items():
#       3         for j in range(len(explanation_name)):
#       4             if key == explanation_name[j].split()[0]:
#
# RuntimeError: dictionary keys changed during iteration

# %%
price_list2
# Out:
# [{'market': 'KRW-BTC',
#   'trade_date': '20240125',
#   'trade_time': '070311',
#   'trade_date_kst': '20240125',
#   'trade_time_kst': '160311',
#   'trade_timestamp': 1706166191687,
#   'opening_price': 55200000.0,
#   'high_price': 55401000.0,
#   'low_price': 54900000.0,
#   'trade_price': 55138000.0,
#   'prev_closing_price': 55200000.0,
#   'change': 'FALL',
#   'change_price': 62000.0,
#   'change_rate': 0.0011231884,
#   'signed_change_price': -62000.0,
#   'signed_change_rate': -0.0011231884,
#   'trade_volume': 0.14675015,
#   'acc_trade_price': 47006326911.08512,
#   'acc_trade_price_24h': 162621074677.7586,
#   'acc_trade_volume': 852.8150286,
#   'acc_trade_volume_24h': 2947.5749926,
#   'highest_52_week_price': 66779000.0,
#   'highest_52_week_date': '2024-01-11',
#   'lowest_52_week_price': 26707000.0,
#   'lowest_52_week_date': '2023-03-10',
#   'timestamp': 1706166191704},
#  {'market': 'KRW-ETH',
#   'trade_date': '20240125',
#   'trade_time': '070300',
# ...
